# %%
T = graphs.RandomTree(6)
T.show()
# Out:
# Graphics object consisting of 12 graphics primitives

# %%
T.vertices()
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
T.degree()
# Out:
# [1, 2, 1, 2, 1, 3]

# %%
leaves= [v for v in T.vertices() if T.degree(v) == 1]
leaves
# Out:
# [0, 2, 4]

# %%
D = T.distance_matrix()
D
# Out:
# [0 3 3 1 4 2]
# [3 0 2 2 1 1]
# [3 2 0 2 3 1]
# [1 2 2 0 3 1]
# [4 1 3 3 0 2]
# [2 1 1 1 2 0]

# %%
D_leaves = D.matrix_from_rows_and_columns(leaves, leaves)
D_leaves
# Out:
# [0 3 4]
# [3 0 3]
# [4 3 0]

# %%
labels = {leaves[i]: f"S{i+1}" for i in range(len(leaves))}
T.show(vertex_labels=labels, vertex_colors ={'lightgreen': leaves})
#T_labeled = T.relabel(labels, inplace = False)
#T_labeled.show()
# Out:
# Graphics object consisting of 12 graphics primitives
