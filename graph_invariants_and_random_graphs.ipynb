# %%
2+3
# Out:
# x^2 + 3*x + 1

# %%
x= var('x')
x^2 + 3*x + 1
# Out:
# x^2 + 3*x + 1

# %%
f(x)= x^2 - 3
f(3)
# Out:
# 6

# %%
L =[ 1, 2, 3, 4]
sum (L)
# Out:
# 10

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
L = [1, 2, 3, 4]
sum(L)

for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
help(Graph)
# Out:
# WARNING: Some output was deleted.

# %%
Graph(5)
# Out:
# Graph on 5 vertices

# %%
G = graphs.CycleGraph(5)
G
# Out:
# Cycle graph: Graph on 5 vertices

# %%
G.show()
G.chromatic_number()
# Out:
# Graphics object consisting of 11 graphics primitives
# 3

# %%
G.degree_sequence()
# Out:
# [2, 2, 2, 2, 2]

# %%
G = graphs.CycleGraph(6)
G.show()
# Out:
# Graphics object consisting of 13 graphics primitives

# %%
G.vertices()
G.edges()
G.order()  #number of vertices
G.size()   #number of edges
# Out:
# 6

# %%
G.degree_sequence ()
# Out:
# [2, 2, 2, 2, 2, 2]

# %%
G.is_connected()
G.is_bipartite()
G.chromatic_number()
G.clique_number()
# Out:
# 2

# %%
H = graphs.CompleteGraph(5)
H.show()

H.chromatic_number()
H.clique_number()
# Out:
# Graphics object consisting of 16 graphics primitives
# 5

# %%
R = graphs.RandomGNP(10,0.3)
R.show()
# Out:
# Graphics object consisting of 23 graphics primitives

# %%
R.is_connected()
R.chromatic_number()
#R.degree_sequence()
#R.clique_number()
# Out:
# 4

# %%
R.shortest_path(0,5)
R.diameter()
# Out:
# 3

# %%
M=R.matching()
M
# Out:
# [(0, 7, None), (1, 2, None), (3, 6, None), (4, 5, None), (8, 9, None)]

# %%
for p in [0.2, 0.4, 0.6]:
    G = graphs.RandomGNP(12, p)
    print("p =", p,
          "chromatic =", G.chromatic_number(),
          "connected =", G.is_connected())
# Out:
# p = 0.200000000000000 chromatic = 3 connected = False
# p = 0.400000000000000 chromatic = 3 connected = True
# p = 0.600000000000000 chromatic = 4 connected = True

# %%
G=graphs.CycleGraph(6)
G.show()
# Out:
# Graphics object consisting of 13 graphics primitives

# %%
G.vertices()
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
G.edges(labels=False)
# Out:
# [(0, 1), (0, 5), (1, 2), (2, 3), (3, 4), (4, 5)]

# %%
G.degree_sequence()
# Out:
# [2, 2, 2, 2, 2, 2]

# %%
G.chromatic_number()
# Out:
# 2

# %%
G.cliques_maximum()
# Out:
# [[0, 1], [0, 5], [1, 2], [2, 3], [3, 4], [4, 5]]

# %%
G.independent_set()
# Out:
# [0, 2, 4]

# %%
len(G.independent_set())
# Out:
# 3

# %%
G= graphs.CycleGraph(6)

G.show()
G.clique_number()
len(G.independent_set())
G.order()
G.size()

H= G.complement()

H.show(layout='spring')
len(G.independent_set())
H.clique_number()
G.size()
H.size()
# Out:
# Graphics object consisting of 13 graphics primitives
# Graphics object consisting of 16 graphics primitives
# 9

# %%
G= graphs.PathGraph(6)

G.show()
G.clique_number()
len(G.independent_set())
G.order()
G.size()
# Out:
# Graphics object consisting of 12 graphics primitives
# 5

# %%
G=graphs.PathGraph(6)
H= G.complement()

H.show(layout='spring')
len(G.independent_set())
#H.clique_number()
#G.size()
H.size()
# Out:
# Graphics object consisting of 17 graphics primitives
# 10

# %%
G= graphs.CompleteGraph(6)

G.show()
G.clique_number()
len(G.independent_set())
G.order()
G.size()
# Out:
# Graphics object consisting of 22 graphics primitives
# 15

# %%
Gc= G.complement()

Gc.show()
len(G.independent_set())
Gc.clique_number()
# Out:
# Graphics object consisting of 7 graphics primitives
# 1

# %%
G = graphs.RandomGNP(12,0.6)
G.show()
G.clique_number()
# Out:
# Graphics object consisting of 56 graphics primitives
# 5

# %%
len(G.independent_set())

#G.is_connected()
# Out:
# 4

# %%
H= G.complement()

H.show(layout='circular')
#len(G.independent_set())
H.clique_number()
#G.size()
#H.size()
# Out:
# Graphics object consisting of 36 graphics primitives
# 4

# %%
G.degree_sequence()
max(G.degree())
# Out:
# 10
